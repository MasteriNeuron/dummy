# %%
def sum1(a,b):
    print("hell0")

# %%
(a+b)
# Out:
# 5

# %%
a,b=2,3
sum1(a,b)
# Out:
# hell0
# 5

# %%
import pandas
from pandas_datareader import data as pdr
import yfinance as yfin
yfin.pdr_override()


df = pdr.get_data_yahoo("TSLA", start="2019-01-01", end="2019-03-31")
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2019-01-02  20.406668  21.008667  19.920000  20.674667  20.674667  174879000
# 2019-01-03  20.466667  20.626667  19.825333  20.024000  20.024000  104478000
# 2019-01-04  20.400000  21.200001  20.181999  21.179333  21.179333  110911500
# 2019-01-07  21.448000  22.449333  21.183332  22.330667  22.330667  113268000
# 2019-01-08  22.797333  22.934000  21.801332  22.356667  22.356667  105127500
# ...               ...        ...        ...        ...        ...        ...
# 2019-03-25  17.313999  17.545334  16.964001  17.361334  17.361334  153225000
# 2019-03-26  17.629333  18.017332  17.628668  17.851334  17.851334  110263500
# 2019-03-27  17.916668  18.358000  17.878668  18.322001  18.322001  131688000
# 2019-03-28  18.477333  18.688667  18.340000  18.574667  18.574667  101611500
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the data points for classes A and B
class_A = np.array([(3, 1), (3, 4), (3, 5), (2, 5), (4, 5), (4, 6)])
class_B = np.array([(5, 1), (5, 3), (5, 4), (6, 1), (6, 2), (7, 1), (7, 2)])

# Function to plot data points
def plot_data(class_A, class_B):
    plt.scatter(class_A[:, 0], class_A[:, 1], marker='o', label='Class A')
    plt.scatter(class_B[:, 0], class_B[:, 1], marker='x', label='Class B')

# Define a function to plot the decision boundary
def plot_decision_boundary(w0, w1, w2, title):
    x_range = np.linspace(1, 8, 800)
    y_range = np.linspace(0, 7, 800)
    X, Y = np.meshgrid(x_range, y_range)
    Z = w0 + w1 * X + w2 * Y
    
    plt.contour(X, Y, Z, levels=[0], colors='k', linestyles='dashed')
    plt.title(title)

# Scenario (a): Lasso Regularization on All Parameters
w0_a, w1_a, w2_a = 0.5, -0.5, 0.5
plt.figure(figsize=(12, 4))
plt.subplot(131)
plot_data(class_A, class_B)
plot_decision_boundary(w0_a, w1_a, w2_a, "Lasso on All Parameters")

# Scenario (b): Lasso Regularization on w0 Only
w0_b, w1_b, w2_b = 0, -0.5, 0.5
plt.subplot(132)
plot_data(class_A, class_B)
plot_decision_boundary(w0_b, w1_b, w2_b, "Lasso on w0 Only")

# Scenario (c): Lasso Regularization on w1 Only
w0_c, w1_c, w2_c = 0.5, -0.0000001, 0.5
plt.subplot(133)
plot_data(class_A, class_B)
plot_decision_boundary(w0_c, w1_c, w2_c, "Lasso on w1 Only")

plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the data points for classes A and B
class_A = np.array([(3, 1), (3, 4), (3, 5), (2, 5), (4, 5), (4, 6)])
class_B = np.array([(5, 1), (5, 3), (5, 4), (6, 1), (6, 2), (7, 1), (7, 2)])

# Define the regularization parameter (lambda)
lambda_value = 0.1  # You can adjust this value

# Function to calculate sigmoid
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

# Function to calculate decision boundary
def decision_boundary(w0, w1, w2, x1, x2):
    z = w0 + w1 * x1 + w2 * x2
    return sigmoid(z)

# Generate data points for the decision boundary
x1 = np.linspace(1, 8, 400)
x2 = np.linspace(1, 7, 350)
X1, X2 = np.meshgrid(x1, x2)
Y = decision_boundary(0, 0, 0, X1, X2)

# Create a 3D plot
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Plot data points for class A and class B
ax.scatter(class_A[:, 0], class_A[:, 1], np.zeros_like(class_A[:, 0]), c='b', marker='o', label='Class A')
ax.scatter(class_B[:, 0], class_B[:, 1], np.zeros_like(class_B[:, 0]), c='r', marker='x', label='Class B')

# Plot the decision boundary
ax.plot_surface(X1, X2, Y, cmap='viridis', alpha=0.5, antialiased=True)

# Set labels and legend
ax.set_xlabel('X1')
ax.set_ylabel('X2')
ax.set_zlabel('Probability')
ax.set_title('Decision Boundary in 3D')

# Show legend
ax.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define data points for classes A and B
class_A = np.array([(3, 1), (3, 4), (3, 5), (2, 5), (4, 5), (4, 6)])
class_B = np.array([(5, 1), (5, 3), (5, 4), (6, 1), (6, 2), (7, 1), (7, 2)])

# Helper function to plot data points
def plot_data_points(class_A, class_B):
    plt.scatter(class_A[:, 0], class_A[:, 1], marker='o', label='Class A')
    plt.scatter(class_B[:, 0], class_B[:, 1], marker='x', label='Class B')

# Define the decision boundary equations for each case

# (a) Decision boundary for optimal model (Lasso on all parameters)
def decision_boundary_optimal(x):
    w0, w1, w2 = 0.0, 0.0, 0.0  # Replace with actual values
    return (-w0 - w1 * x) / w2

# (b) Decision boundary with Lasso regularization on w0 only
def decision_boundary_regularize_w0(x):
    w0, w1, w2 = 0.0, 0.0, 0.0  # Replace with actual values
    return (-w0 - w1 * x) / w2

# (c) Decision boundary with Lasso regularization on w1 only
def decision_boundary_regularize_w1(x):
    w0, w1, w2 = 0.0, 0.0, 0.0  # Replace with actual values
    return (-w0 - w1 * x) / w2

# Create a range of x values for plotting
x_range = np.linspace(1, 8, 100)

# Create subplots for each case
plt.figure(figsize=(15, 5))

# Plot for (a)
plt.subplot(131)
plot_data_points(class_A, class_B)
plt.plot(x_range, decision_boundary_optimal(x_range), label='Decision Boundary')
plt.title('Decision Boundary (Optimal)')
plt.legend()

# Plot for (b)
plt.subplot(132)
plot_data_points(class_A, class_B)
plt.plot(x_range, decision_boundary_regularize_w0(x_range), label='Decision Boundary')
plt.title('Decision Boundary (Regularize w0)')
plt.legend()

# Plot for (c)
plt.subplot(133)
plot_data_points(class_A, class_B)
plt.plot(x_range, decision_boundary_regularize_w1(x_range), label='Decision Boundary')
plt.title('Decision Boundary (Regularize w1)')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_19820\469771348.py:18: RuntimeWarning: invalid value encountered in divide
#   return (-w0 - w1 * x) / w2
# C:\Users\pc\AppData\Local\Temp\ipykernel_19820\469771348.py:23: RuntimeWarning: invalid value encountered in divide
#   return (-w0 - w1 * x) / w2
# C:\Users\pc\AppData\Local\Temp\ipykernel_19820\469771348.py:28: RuntimeWarning: invalid value encountered in divide
#   return (-w0 - w1 * x) / w2

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import *

# %%
lefdt=pd.read_csv('churn.csv')

# %%
lefdt.head(5)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
lefdt[lefdt.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customerID, gender, SeniorCitizen, Partner, Dependents, tenure, PhoneService, MultipleLines, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
lefdt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
lefdt[lefdt['TotalCharges'] == " "]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
lefdt['TotalCharges']=pd.to_numeric(lefdt['TotalCharges'],errors='coerce')

# %%
lefdt.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
isn=lefdt

# %%
for i in isn.columns:
    if isn[isn[i]==' ']:
        isn=isn[isn[i]==' '].replace(' ','NaN',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 2
#       1 for i in isn.columns:
# ----> 2     if isn[isn[i]==' ']:
#       3         isn=isn[isn[i]==' '].replace(' ','NaN',inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
isn[isn['TotalCharges'].isnull()].fillna('fige')
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
lefdt.dropna(inplace=True)

# %%
lefdt.drop("customerID",axis=1,inplace=True)

# %%
lefdt.head(3)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges  TotalCharges Churn
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in lefdt.columns:
    if((lefdt[i].dtype=='object') & (i != 'Churn')):
        lefdt[i]=le.fit_transform(lefdt[i])

# %%
lefdt
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
lefdt.shape
# Out:
# (7032, 20)

# %%
lefdt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   int32
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   int32
#  3   Dependents        7032 non-null   int32
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   int32
#  6   MultipleLines     7032 non-null   int32
#  7   InternetService   7032 non-null   int32
#  8   OnlineSecurity    7032 non-null   int32
#  9   OnlineBackup      7032 non-null   int32
#  10  DeviceProtection  7032 non-null   int32
#  11  TechSupport       7032 non-null   int32
#  12  StreamingTV       7032 non-null   int32
#  13  StreamingMovies   7032 non-null   int32
#  14  Contract          7032 non-null   int32
#  15  PaperlessBilling  7032 non-null   int32
# ...

# %%
X=lefdt.iloc[: ,:-1]
Y=lefdt['Churn']

# %%
Y
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7032, dtype: object

# %%
X
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
spl=train_test_split

# %%
X_train,X_test,Y_train,Y_test=spl(X,Y,test_size=0.2, random_state=455)

# %%
print(X_test.shape)
# Out:
# (1407, 19)

# %%
classifier=RandomForestClassifier()
classifier.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=classifier.predict(X_test)

# %%
accuracy_score(y_pred,Y_test)
# Out:
# 0.7896233120113717

# %%
from  sklearn.model_selection import GridSearchCV

# %%
param_grid={
    'n_estimators':[100,200],
    'criterion':['gini','entropy'],
    'max_depth':[None,5,7],
    'min_samples_split': [2,5,9],
    'min_samples_leaf': [1,2,5]
    
}

# %%
rf=RandomForestClassifier()

# %%
grid_ser=GridSearchCV(estimator=rf, param_grid=param_grid, cv=2)

# %%
grid_ser.fit(X_train, Y_train)
# Out:
# GridSearchCV(cv=2, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 7],
#                          'min_samples_leaf': [1, 2, 5],
#                          'min_samples_split': [2, 5, 9],
#                          'n_estimators': [100, 200]})

# %%
d1 = {'234': "vaibhav", 'email': "vaibhav.ai@gmail.com", 'mobile': 1234567892}
d1['234']  # Accessing value using correct key
# Out:
# 'vaibhav'
